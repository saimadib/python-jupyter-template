# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
# TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    # TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.


def plot_histogram(data, bins=None, title="Histogram of Data Values", xlabel="Value", ylabel="Frequency", color='tab:blue'):
    """
    Creates a histogram for a list of numerical data.

    Parameters:
    - data (list of numeric): The input values to bin.
    - bins (int or sequence, optional): Defines the bin edges or number of bins.
    - title (str): Title of the histogram.
    - xlabel (str): Label for the x-axis.
    - ylabel (str): Label for the y-axis.
    - color (str): Bar color.

    Returns:
    - None: Displays the histogram.

    Example:
        >>> plot_histogram([1,2,2,3,3,3])
    """
    logger.debug("Entering plot_histogram function.")
    fig, ax = plt.subplots(figsize=(8, 6))
    logger.debug(f"Plotting histogram data={data}, bins={bins}, color={color}.")
    ax.hist(data, bins=bins, edgecolor='black', color=color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', alpha=0.7, linestyle=':')
    plt.tight_layout()
    logger.info("Displaying histogram.")
    plt.show()
    logger.debug("Exiting plot_histogram function.")
    print("test")

    print("test")
